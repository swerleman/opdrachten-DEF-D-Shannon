# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 2 invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in (als in *PR* op GitHub en de link op Brightspace). Zet jullie groepsnummer, studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.
#
# | Groep: 9     |  |
# | :-------------|:-------------|
# | Shannon Werleman| 6292933|
# | Ties Langeraar| 6541798 |
# | Student naam 3| Student Studienummer 3 |
# | Planning Groep: 09     |Tijdstip / Tijdspanne  |
# |---|---|
# | Sanity check 1 | 11:20 |
# | Sanity check 2 | 11:50 |
# | Sanity check 3| 12:30 |
# | Synthese + evaluatie | 14:00 |
# | Simulatie | 14:30 |
# | Bouwen 15:00 |
# | Kalibratiemeting | 15:30 |
# | Iteratie | 16:10 |
# | Uiteindelijke resultaat en conclusie| 16:30 |
# | Opruimen| 17:30 |
# | groep aanwezig 2| Tijdspanne |
# | Pauze 1| 12:30-13:30 |
# | Pauze 2| 15:30-15:45|

# %% [markdown]
# ## *Opdracht 1*: Sanity check 3

# %% [markdown]
# #### Voeg hier een foto van de schets van je plaatcondensator in. Geef daarbij ook duidelijk de waarde van $A$ en $d$ aan.
# <img src="IMG_4700.jpg" alt="schets student 1" width="400"/>
#
#
#  Schrijf hier een python functie die de capaciteit van een plaatcondensator uitrekent. Zorg dat de functie
#  als input de ontwerpparameters van de vlakke plaat formule accepteert (oppervlakte, afstand en diëlektrische
# constante) en als output de capaciteit van de vlakke plaat condensator met die ontwerpparameters.
#  Je gaat deze formule de rest van de dag gebruiken: controleer hem goed!
#
# def functieNaam(jouwInputs):
#     output = jouwInputs
#     return output
#
# # Optioneel: schrijf je functie zodanig dat je arrays als input kan geven en (dus) ook arrays als output.

# %%
import numpy as np

def capaciteit_plaatcondensator(oppervlakte, afstand, epsilon_r):
    
    epsilon_0 = 8.854e-12  # F/m 
    
    C = epsilon_0 * epsilon_r * (oppervlakte / afstand)
    
    return C


c = capaciteit_plaatcondensator(0.01, 0.00107, 2)
print(f"De capaciteit van de plaatcondensator is: {c:.2e} F")

def capaciteit_plaatcondensator_ampere(stroom, spanning, f):
    
    C = stroom / (spanning * 2 * np.pi * f) 
    
    return C

c_ampere = capaciteit_plaatcondensator_ampere((1.65/1000), 8.0, 100000)
print(f"Berekende capaciteit plaatcondensator groep 9 is {c_ampere:.2e} F")

epsilon_0 = 8.854e-12
# Out:
# De capaciteit van de plaatcondensator is: 1.65e-10 F
# Berekende capaciteit plaatcondensator groep 9 is 3.28e-10 F

# %% [markdown]
# #### Voeg hier een foto van je plaatcondensator en van de meting op de scope in. Dus 2 foto's.
# ![scope meting 1](IMG_4702.jpg)
# ![scope meting 2](IMG_4703.jpg)

# %% [markdown]
# ### Meting capaciteit
# Vul onderstaande tabel in. Bij Sanity check 2 heb je afgeleid hoe je van berekende capaciteit naar berekend voltage gaat en terug.
#
#
# | Namen         | Berekende capaciteit   | Berekend Voltage | Gemeten Voltage | Gemeten capaciteit   |
# |-------------|-------------:|-------------:|-------------:|-------------:|
# | groep 9| 165 pF |0.83 V | 328 pF |1.65 V |

# %% [markdown]
# ## *Opdracht 2:* Synthese.

# %% [markdown]
# #### Voeg hier voor een foto van je schets(en) van minimaal drie sensoren in.
# Afstand sensor:
# ![drie schetsen](IMG_4709.jpg)
# Oppervlakte sensor:
# ![drie schetsen](IMG_4710.jpg)
# Dielektrische sensor:
# ![drie schetsen](IMG_4711.jpg)

# %% [markdown]
# ## Opdracht 3: Welke sensor gaan jullie maken?

# %% [markdown]
# Pas deze tekst aan: Kracht sensor

# %% [markdown]
# ## Opdracht 4: Uitgewerkte schets (afmetingen!) en plot van de ontwerpgrafiek.

# %% [markdown]
# #### Voeg hier een foto van jullie uitgewerkte  schets van de sensor die jullie gaan maken in
# ![uitgewerkte schets](IMG_4716.jpg)

# %%
# Plot hier de verwachte ontwerpgrafiek van jullie sensoren.
amax_metplaat = 6.60 #mm
amin_metplaat = 3.74 #mm

plaatdikte = 1.43 #mm

amax = (amax_metplaat - (2 *plaatdikte)) / 1000 #m
amin = (amin_metplaat - (2* plaatdikte)) / 1000 #m
agem = ((amax + amin) / 2) #m
print(amax*1000, amin*1000, "gemeten afstand", agem*1000, "mm")

print("Minimale capaciteit:", capaciteit_plaatcondensator(0.01, amax, 1), "F")
print("Maximale capaciteit:", capaciteit_plaatcondensator(0.01, amin, 1), "F")
print("Gemiddelde capaciteit:", capaciteit_plaatcondensator(0.01, agem, 1), "F")
# Out:
# 3.7399999999999998 0.8800000000000003 gemeten afstand 2.31 mm
# Minimale capaciteit: 2.367379679144385e-11 F
# Maximale capaciteit: 1.0061363636363632e-10 F
# Gemiddelde capaciteit: 3.832900432900433e-11 F

# %% [markdown]
# ## Opdracht 5: Invullen tabel LTSpice.

# %% [markdown]
# |         | Capaciteit waarde (pF)  | LTSpice berekend output Vpp (mV)|
# |-------------|-------------:|-------------:|
# | minmale capaciteit| 23.6 pF |119 mV |
# | gemiddelde capaciteit|38.3 pF |192 mV |
# | maximale capaciteit| 101 pF | 506 mV |

# %% [markdown]
# ## Opdracht 6: Foto's werkende opstelling.

# %% [markdown]
# #### Voeg hier de foto's van je sensoren in actie in.
# ![meting 1](IMG_4717.jpg)
# ![meting 2](IMG_4718.jpg))

# %% [markdown]
# ## Opdracht 7: Plot de kalibratiegrafiek.

# %%
# Plot hier je gemeten kalibratiegrafiek en plot in dezelfde figuur ook je verwachte ontwerpgrafiek.
import matplotlib.pyplot as plt
Minimale_spanning_osc = 190 #mV

g=9.81
u = np.array([0, 2, 9]) #kg
gemeten_capaciteit1 = np.array([23.6, 38.3, 101]) #pF


def c_functie_nieuw(m,epsilon_r,A,d_0,k):
    return(epsilon_0*epsilon_r*A)/(d_0-(m*g/k))*10e12

test_massa = np.linspace(0,9,1000)

plt.figure(figsize=(10, 6))
plt.plot(u, gemeten_capaciteit1, 'o-', label='Gemeten Capaciteit')
#spons is heel veel lucht, dus we hebben dezelfde epsilonr genomen. We hebben een kleine delta_d, om een nette lijn te kunnen maken. 
#De veerconstante is genomen van een spons, dus ongeveer 30 kPa. Dit is geschat gebaseerd op de elasticiteit van onze spons vergeleken met andere materialen waarvan de E wel duidelijk was. 
plt.plot(test_massa,c_functie_nieuw(test_massa,1,0.1*0.1,0.005,40000), label = 'Verwachtte Capaciteit')
plt.xlabel('massa (kg)')
plt.ylabel('Capaciteit (pF)')
plt.title('Kalibratiegrafiek van de Sensor')
plt.legend()
plt.grid()
plt.show()  



#Zoals te zien lijken de grafiek een beetje op elkaar, toch zijn ze niet gelijk. 
#Dit komt waarschijnlijk o.a. doordat de veerconsante geschat is, en doordat we geen rekening gehouden hebben met een startende capaciteit.

# %% [markdown]
# ## Opdracht 8: Vul de tekst aan.

# %% [markdown]
# Onze sensor kan nog verbetered worden door de volgende verbeteringen (minimaal 2):
#
# Iets elastischer middem die twee platen zetten in plaats van spons.
# Een grotere plaat oppervlak zodat er grotere objecten erop kunt zetten.

# %% [markdown]
# ## Opdracht 9: Uiteindelijke ontwerp en kalibratiegrafiek.

# %% [markdown]
# #### Voeg hier een foto van je uiteindelijke sensor in.
# ![foto sensor](IMG_4720.jpg)

# %%
# Plot hier je oorspronkelijke en je uiteindelijke kalibratiegrafieken, fit daar een bijpassende lijn door
# en zet ook de verwachte ontwerpgrafiek erbij
# Plot hier je gemeten kalibratiegrafiek en plot in dezelfde figuur ook je verwachte ontwerpgrafiek.
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
Minimale_spanning_osc = 190 #mV

massa = np.array([0, 0.454, 0.600, 1.0 , 1.6, 2.6, 3.6, 4.1,6.2, 10]) #kg
gemeten_capaciteit = np.array([111.1, 113.0, 113.5, 114.9, 116.9, 119.0 ,123.7, 125.6 ,127.7 ,136.6]) #pF

u_massa = 0.5e-3 #weegschaal meet op gram
u_bits = np.array([4,3,5,2,3,4,2,1,4,5]) #gebaseerd op oscilaties van de bits

# physics-linearized model: Cbegin is massa 0  en a is de stijging van C per kg a = dC/dm
def model(m, Cbegin, a):
    return Cbegin + a*m

popt, pcov = curve_fit(model, massa, gemeten_capaciteit)
Cbegin, a = popt

print(f"C(m) = {Cbegin:.3f} + {a:.3f} * m   [pF]")
print("pcov:\n", pcov)

m_fit = np.linspace(massa.min(), massa.max(), 300)
C_fit = model(m_fit, *popt)

plt.figure(figsize=(10,6))
plt.errorbar(massa, gemeten_capaciteit, xerr=u_massa,yerr=u_bits, fmt='o', label='Gemeten data')
plt.plot(m_fit, C_fit, '-', label='Fit van condensator model')
plt.xlabel('Massa (kg)')
plt.ylabel('Capaciteit (pF)')
plt.title('Massa vs Capaciteit (lineair, fysisch onderbouwd)')
plt.grid(True)
plt.legend()
plt.show()


u = np.array([0, 2, 9]) #kg
gemeten_capaciteit1 = np.array([23.6, 38.3, 101]) #pF

def c_functie(epsilon_r,delta_d,E_modulus,massa):
    return (epsilon_0*epsilon_r*g*massa)/(delta_d*E_modulus)*10e12

test_massa = np.linspace(0,9,1000)

plt.figure(figsize=(10, 6))
plt.plot(u, gemeten_capaciteit1, 'o-', label='Gemeten Capaciteit')
plt.plot(test_massa,c_functie_nieuw(test_massa,1,0.1*0.1,0.005,40000), label = 'Verwachtte Capaciteit')
plt.xlabel('massa (kg)')
plt.ylabel('Capaciteit (pF)')
plt.title('Kalibratiegrafiek van de Sensor')
plt.legend()
plt.grid()
plt.show()
# Out:
# C(m) = 112.531 + 2.543 * m   [pF]
# pcov:
#  [[ 0.41180866 -0.06933527]
#  [-0.06933527  0.02299372]]

# %% [markdown]
# ## Opdracht 10: Vul hieronder de conclusie in.

# %% [markdown]
# ## Conclusie
#
# Uit de metingen blijkt dat de capaciteit van de condensator lineair toeneemt met de massa die op de sensor wordt geplaatst. De lineaire fit van de meetdata geeft:
#
# $C(m) = 112.53 + 2.54\,m \quad [pF]$
#
# Dit betekent dat de sensor een gevoeligheid van ongeveer $2.54\,pF/kg$** heeft.
#
# Als er massa op de spons wordt geplaatst worden de platen dichter naar elkaar gedrukt. Daardoor neemt de capaciteit van de condensator toe. Met deze formule is te zien wat de capaciteit is:
#
# $C = \frac{\varepsilon A}{d}$
#
# neemt de capaciteit toe wanneer de plaatafstand $d$ kleiner wordt.
#
# Voor kleine vervormingen van de spons kan deze relatie worden benaderd als lineair, wat overeenkomt met de gemeten data.
#
# Daarnaast laat de kalibratiegrafiek tussen spanning en capaciteit (gemeten met oscilloscoop) zien dat ook deze lijn ook lineair is. Dit betekent dat de sensor goed kan worden gebruikt om massa te bepalen.
#
# De sensor kan worden gebruikt als een kracht sensor. De massa wordt door de elasticiteit van de spons wordt omgezet in een verandering van capaciteit.

# %% [markdown]
# ## Opdracht 11: Kopieer hieronder de leerdoelen.
# 1. Het kunnen gebruiken van de eigenschappen van een elektrische component in een ontwerpproces om een fysische grootheid te meten.
# 2. Kennis hebben van gedrag van elektrische componenten en meetopstellingen.
# 3. Onderdelen van een datasheet zoals een kalibratiegrafiek opstellen, gevoeligheid en onzekerheid beschrijven.

# %% [markdown]
# kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 1 beheersen.

# %% [markdown]
# #### Voeg hier een foto van je plaatcondensator en van de meting op de scope in. Dus 2 foto's.
# ![scope meting 1](IMG_4702.jpg)
# ![scope meting 2](IMG_4703.jpg)

# %%
import matplotlib.pyplot as plt
Minimale_spanning_osc = 190 #mV

g=9.81
u = np.array([0, 2, 9]) #kg
gemeten_capaciteit1 = np.array([23.6, 38.3, 101]) #pF


def c_functie_nieuw(m,epsilon_r,A,d_0,k):
    return(epsilon_0*epsilon_r*A)/(d_0-(m*g/k))*10e12

test_massa = np.linspace(0,9,1000)

plt.figure(figsize=(10, 6))
plt.plot(u, gemeten_capaciteit1, 'o-', label='Gemeten Capaciteit')
#spons is heel veel lucht, dus we hebben dezelfde epsilonr genomen. We hebben een kleine delta_d, om een nette lijn te kunnen maken. 
#De veerconstante is genomen van een spons, dus ongeveer 30 kPa. Dit is geschat gebaseerd op de elasticiteit van onze spons vergeleken met andere materialen waarvan de E wel duidelijk was. 
plt.plot(test_massa,c_functie_nieuw(test_massa,1,0.1*0.1,0.005,40000), label = 'Verwachtte Capaciteit')
plt.xlabel('massa (kg)')
plt.ylabel('Capaciteit (pF)')
plt.title('Kalibratiegrafiek van de Sensor')
plt.legend()
plt.grid()
plt.show()  



#Zoals te zien lijken de grafiek een beetje op elkaar, toch zijn ze niet gelijk. 
#Dit komt waarschijnlijk o.a. doordat de veerconsante geschat is, en doordat we geen rekening gehouden hebben met een startende capaciteit.

# %% [markdown]
# kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 2 beheersen.
#
# #### Voeg hier de foto's van je sensoren in actie in.
# ![meting 1](IMG_4717.jpg)
# ![meting 2](IMG_4718.jpg))

# %% [markdown]
# kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 3 beheersen.

# %%
# Plot hier je oorspronkelijke en je uiteindelijke kalibratiegrafieken, fit daar een bijpassende lijn door
# en zet ook de verwachte ontwerpgrafiek erbij
# Plot hier je gemeten kalibratiegrafiek en plot in dezelfde figuur ook je verwachte ontwerpgrafiek.
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
Minimale_spanning_osc = 190 #mV

massa = np.array([0, 0.454, 0.600, 1.0 , 1.6, 2.6, 3.6, 4.1,6.2, 10]) #kg
gemeten_capaciteit = np.array([111.1, 113.0, 113.5, 114.9, 116.9, 119.0 ,123.7, 125.6 ,127.7 ,136.6]) #pF

u_massa = 0.5e-3 #weegschaal meet op gram
u_bits = np.array([4,3,5,2,3,4,2,1,4,5]) #gebaseerd op oscilaties van de bits, aangezien de onzekerheid veroorzaakt door de massa hierbij verwaarloosbaar is.

# physics-linearized model: Cbegin is massa 0  en a is de stijging van C per kg a = dC/dm
def model(m, Cbegin, a):
    return Cbegin + a*m

popt, pcov = curve_fit(model, massa, gemeten_capaciteit)
Cbegin, a = popt

print(f"C(m) = {Cbegin:.3f} + {a:.3f} * m   [pF]")
print("pcov:\n", pcov)

m_fit = np.linspace(massa.min(), massa.max(), 300)
C_fit = model(m_fit, *popt)

plt.figure(figsize=(10,6))
plt.errorbar(massa, gemeten_capaciteit, xerr=u_massa,yerr=u_bits, fmt='o', label='Gemeten data')
plt.plot(m_fit, C_fit, '-', label='Fit van condensator model')
plt.xlabel('Massa (kg)')
plt.ylabel('Capaciteit (pF)')
plt.title('Massa vs Capaciteit (lineair, fysisch onderbouwd)')
plt.grid(True)
plt.legend()
plt.show()


import matplotlib.pyplot as plt
Minimale_spanning_osc = 190 #mV

g=9.81
u = np.array([0, 2, 9]) #kg
gemeten_capaciteit1 = np.array([23.6, 38.3, 101]) #pF


def c_functie_nieuw(m,epsilon_r,A,d_0,k):
    return(epsilon_0*epsilon_r*A)/(d_0-(m*g/k))*10e12

test_massa = np.linspace(0,9,1000)

plt.figure(figsize=(10, 6))
plt.plot(u, gemeten_capaciteit1, 'o-', label='Gemeten Capaciteit')
#spons is heel veel lucht, dus we hebben dezelfde epsilonr genomen. We hebben een kleine delta_d, om een nette lijn te kunnen maken. 
#De veerconstante is genomen van een spons, dus ongeveer 30 kPa. Dit is geschat gebaseerd op de elasticiteit van onze spons vergeleken met andere materialen waarvan de E wel duidelijk was. 
plt.plot(test_massa,c_functie_nieuw(test_massa,1,0.1*0.1,0.005,40000), label = 'Verwachtte Capaciteit')
plt.xlabel('massa (kg)')
plt.ylabel('Capaciteit (pF)')
plt.title('Kalibratiegrafiek van de Sensor')
plt.legend()
plt.grid()
plt.show()  



#Zoals te zien lijken de grafiek een beetje op elkaar, toch zijn ze niet gelijk. 
#Dit komt waarschijnlijk o.a. doordat de veerconsante geschat is, en doordat we geen rekening gehouden hebben met een startende capaciteit.
# Out:
# C(m) = 112.531 + 2.543 * m   [pF]
# pcov:
#  [[ 0.41180866 -0.06933527]
#  [-0.06933527  0.02299372]]

# %% [markdown]
# ## Conclusie
#
# Uit de metingen blijkt dat de capaciteit van de condensator lineair toeneemt met de massa die op de sensor wordt geplaatst. De lineaire fit van de meetdata geeft:
#
# $C(m) = 112.53 + 2.54\,m \quad [pF]$
#
# Dit betekent dat de sensor een gevoeligheid van ongeveer $2.54\,pF/kg$** heeft.
#
# Als er massa op de spons wordt geplaatst worden de platen dichter naar elkaar gedrukt. Daardoor neemt de capaciteit van de condensator toe. Met deze formule is te zien wat de capaciteit is:
#
# $C = \frac{\varepsilon A}{d}$
#
# neemt de capaciteit toe wanneer de plaatafstand $d$ kleiner wordt.
#
# Voor kleine vervormingen van de spons kan deze relatie worden benaderd als lineair, wat overeenkomt met de gemeten data.
#
# Daarnaast laat de kalibratiegrafiek tussen spanning en capaciteit (gemeten met oscilloscoop) zien dat ook deze lijn ook lineair is. Dit betekent dat de sensor goed kan worden gebruikt om massa te bepalen.
#
# De sensor kan worden gebruikt als een kracht sensor. De massa wordt door de elasticiteit van de spons wordt omgezet in een verandering van capaciteit.
